# %%
import wandb

import torch
import torch.nn as nn
from gymnasium import spaces
from qiskit.transpiler import CouplingMap
from stable_baselines3 import PPO
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor

from ai_linear_function_synthesis.env import *
# Out:
# /home/ojun/.local/share/virtualenvs/utokyo-qiskit-fall-fest-2025-qurl-JwMW5MNU/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:76: UserWarning: The minimal resolution for an image is 36x36 for the default `CnnPolicy`. You might need to use a custom features extractor cf. https://stable-baselines3.readthedocs.io/en/master/guide/custom_policy.html
#   warnings.warn(

# %%
NUM_QUBITS = 5
COUPLING_MAP = CouplingMap.from_line(NUM_QUBITS)
BATCH_SIZE = 100
SUCCESS_RATE_THRESHOLD = 0.8

model_class = PPO
NUM_TIME_STEPS = 5 * 10**5

config = {
    "num_qubits": NUM_QUBITS,
    "coupling_map": COUPLING_MAP,
    "eval_batch_size": BATCH_SIZE,
    "success_rate_threshold": SUCCESS_RATE_THRESHOLD,
    "model_class": model_class.__name__,
    "num_time_steps": NUM_TIME_STEPS,
}

device_name = "cpu"
if torch.cuda.is_available():
    device_name = "cuda"
if torch.backends.mps.is_available():
    device_name = "mps"
print(f"device_name: {device_name}")
# Out:
# device_name: cuda

# %%
class CustomCNN(BaseFeaturesExtractor):
    """
    ref: stable-baselines3 documentation & https://github.com/greentfrapp/snake
    :param observation_space: (gym.Space)
    :param features_dim: (int) Number of features extracted.
        This corresponds to the number of unit for the last layer.
    """

    def __init__(self, observation_space: spaces.Box, features_dim: int = 64):
        super().__init__(observation_space, features_dim)
        # We assume CxHxW images (channels first)
        # Re-ordering will be done by pre-preprocessing or wrapper
        n_input_channels = observation_space.shape[0]

        self.cnn = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.Flatten(),
        )

        # Compute shape by doing one forward pass
        with torch.no_grad():
            n_flatten = self.cnn(
                torch.as_tensor(observation_space.sample()[None]).float()
            ).shape[1]

        self.linear = nn.Sequential(
            nn.Linear(n_flatten, features_dim),
            nn.ReLU(),
            nn.Linear(features_dim, features_dim),
            nn.ReLU(),
        )

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, (nn.Linear, nn.Conv2d)):
            torch.nn.init.xavier_uniform_(module.weight)
            if module.bias is not None:
                module.bias.data.zero_()

    def forward(self, observations: torch.Tensor) -> torch.Tensor:
        return self.linear(self.cnn(observations))

# %% [markdown]
# ## Curriculum learning + sparse reward

# %%
wandb.init(
    entity="QuRL",
    project="OjunDesktop-ai-linear-function-synthesis",
    name="sparse_and_dence_improved",
    config=config,
)


env = AILinearFunctionSynthesis(
    coupling_map=COUPLING_MAP,
    eval_batch_size=BATCH_SIZE,
    success_rate_threshold=SUCCESS_RATE_THRESHOLD,
    wandb_log=True,
)

# Initialize the model
model = model_class(
    policy="CnnPolicy",
    env=env,
    verbose=1,
    policy_kwargs=dict(
        features_extractor_class=CustomCNN,
        features_extractor_kwargs=dict(features_dim=64),
    ),
    device=device_name,
)

# Train the model
model.learn(
    total_timesteps=NUM_TIME_STEPS,
    log_interval=10**5,
    progress_bar=True,
)

model.save("saved_models/lin_func_curriculum")

wandb.finish()
# Out:
# wandb: Currently logged in as: ojun (ojun-info-alpha) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/home/ojun/dev/utokyo-qiskit-fall-fest-2025-qurl/wandb/run-20251107_211007-w01hqv7o</code>
# Syncing run <strong><a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis/runs/w01hqv7o' target="_blank">sparse_and_dence_improved</a></strong> to <a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis' target="_blank">https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis</a>
#  View run at <a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis/runs/w01hqv7o' target="_blank">https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis/runs/w01hqv7o</a>
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>CNOT count</td><td>▁▁▁▁▁▁▁▁▁▂▂▄▄▂▂▆▃▄▇█▅▂█▂▄▂█▆▃▆▃▃▆▄▃▅█▄▆█</td></tr><tr><td>Difficulty</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▃▃▄▅▅▇█████████████████</td></tr><tr><td>Reward</td><td>▁█▁▁▁▁▁▁█▁██▁▁▁▁▁█▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Success rate</td><td>▁▁▁▂▁▂▄▆▆▄▄▄▆▅▆▆▆▆▆▆▆▆▆▆▇▇▇█▇█▇██▇▇█████</td></tr><tr><td>depth</td><td>▁▁▁▁▁▁▁▁▂▁▁▂▁▃▄▂▅▄▆▄▄▆▄▅▂▄█▂▃▄▄▂▄█▃▄▅▅▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>CNOT count</td><td>13</td></tr><tr><td>Difficulty</td><td>25</td></tr><tr><td>Reward</td><td>-0.00592</td></tr><tr><td>Success rate</td><td>0.96</td></tr><tr><td>depth</td><td>9</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sparse_and_dence_improved</strong> at: <a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis/runs/w01hqv7o' target="_blank">https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis/runs/w01hqv7o</a><br> View project at: <a href='https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis' target="_blank">https://wandb.ai/QuRL/OjunDesktop-ai-linear-function-synthesis</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251107_211007-w01hqv7o/logs</code>

# %% [markdown]
# ## No curriculum learning + sparse reward

# %%
wandb.init(
    project="ai-linear-function-synthesis",
    name="run_no_curriculum",
    config=config,
)


env = AILinearFunctionSynthesisNoCurriculumLearning(
    coupling_map=COUPLING_MAP,
    eval_batch_size=BATCH_SIZE,
    wandb_log=True,
)

# Initialize the model
model = model_class(
    policy="CnnPolicy",
    env=env,
    verbose=1,
    policy_kwargs=dict(
        features_extractor_class=CustomCNN,
        features_extractor_kwargs=dict(features_dim=64),
    ),
    device=device_name,
    learning_rate=0.001,
)

# Train the model
model.learn(
    total_timesteps=NUM_TIME_STEPS,
    log_interval=10**5,
    progress_bar=True,
)

model.save("saved_models/lin_func_no_curriculum")

wandb.finish()
# Out:
# creating run (0.2s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/home/kazuki_main/rlss2025-ai-linear-function-synthesis/wandb/run-20250904_000524-o7f3lnij</code>
# Syncing run <strong><a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis/runs/o7f3lnij' target="_blank">run_no_curriculum</a></strong> to <a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis' target="_blank">https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis</a>
#  View run at <a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis/runs/o7f3lnij' target="_blank">https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis/runs/o7f3lnij</a>
# Output()
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>CNOT count</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Reward</td><td>▁▄▄▆▃█▆▃▁▄▆▄▅█▂▇▁▆▆▆▃█▁█▂▁▆▇▁▃▁▆▂▇▇▁▇▁▆▇</td></tr><tr><td>Success rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>CNOT count</td><td>25</td></tr><tr><td>Reward</td><td>-0.21</td></tr><tr><td>Success rate</td><td>0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">run_no_curriculum</strong> at: <a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis/runs/o7f3lnij' target="_blank">https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis/runs/o7f3lnij</a><br> View project at: <a href='https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis' target="_blank">https://wandb.ai/king-p3nguin-The%20University%20of%20Tokyo/ai-linear-function-synthesis</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250904_000524-o7f3lnij/logs</code>

# %% [markdown]
# ## Curriculum learning + dense reward

# %%
wandb.init(
    project="ai-linear-function-synthesis",
    name="run_dense",
    config=config,
)


env = AILinearFunctionSynthesisDenseReward(
    coupling_map=COUPLING_MAP,
    eval_batch_size=BATCH_SIZE,
    success_rate_threshold=SUCCESS_RATE_THRESHOLD,
    wandb_log=True,
)

# Debug: check whether cnot_gates was initialized
print("debug: hasattr(env, 'cnot_gates') =", hasattr(env, 'cnot_gates'))
print("debug: cnot_gates (or None) ->", getattr(env, 'cnot_gates', None))

# Initialize the model
model = model_class(
    policy="CnnPolicy",
    env=env,
    verbose=1,
    policy_kwargs=dict(
        features_extractor_class=CustomCNN,
        features_extractor_kwargs=dict(features_dim=64),
    ),
    device=device_name,
),

# Train the model
model.learn(
    total_timesteps=NUM_TIME_STEPS,
    log_interval=10**5,
    progress_bar=True,
),

model.save("saved_models/lin_func_dense")

wandb.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# wandb: ERROR The nbformat package was not found. It is required to save notebook history.
#  View run <strong style="color:#cdcd00">run_dense</strong> at: <a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis/runs/7vnfq08x' target="_blank">https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis/runs/7vnfq08x</a><br> View project at: <a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis' target="_blank">https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251105_021105-7vnfq08x/logs</code>
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/home/ojun/dev/utokyo-qiskit-fall-fest-2025-qurl/wandb/run-20251105_021645-vt1o3gj7</code>
# Syncing run <strong><a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis/runs/vt1o3gj7' target="_blank">run_dense</a></strong> to <a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis' target="_blank">https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis</a>
#  View run at <a href='https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis/runs/vt1o3gj7' target="_blank">https://wandb.ai/ojun-info-alpha/ai-linear-function-synthesis/runs/vt1o3gj7</a>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 8
#       1 wandb.init(
#       2     project="ai-linear-function-synthesis",
#       3     name="run_dense",
#       4     config=config,
#       5 )
# ----> 8 env = AILinearFunctionSynthesisDenseReward(
#       9     coupling_map=COUPLING_MAP,
#      10     eval_batch_size=BATCH_SIZE,
#      11     success_rate_threshold=SUCCESS_RATE_THRESHOLD,
#      12     wandb_log=True,
#      13 )
#      15 # Debug: check whether cnot_gates was initialized
#      16 print("debug: hasattr(env, 'cnot_gates') =", hasattr(env, 'cnot_gates'))
#
# File ~/dev/utokyo-qiskit-fall-fest-2025-qurl/ai_linear_function_synthesis/env.py:78, in AILinearFunctionSynthesis.__init__(self, coupling_map, eval_batch_size, success_rate_threshold, wandb_log, render_mode)
#      74 # maximum number of steps in an episode
#      75 # the upperbound is O(n^2 / log n)
#      76 self.max_steps = self.num_qubits**2
# ---> 78 self.reset()
#
# File ~/dev/utokyo-qiskit-fall-fest-2025-qurl/ai_linear_function_synthesis/env.py:163, in AILinearFunctionSynthesis.reset(self, seed, options)
#     157 self._update_difficulty()
#     159 if self.wandb_log:
#     160     wandb.log(
#     161         {
#     162             "CNOT count": self.num_cnots,
# --> 163             "depth": self._make_quantum_circuit().depth()
#     164         }
#     165     )
#     167 self.state = linear_function_circuit_to_binary_matrix(
#     168     random_linear_function_circuit_by_difficulty(
#     169         self.num_qubits, self.difficulty, self.coupling_map
#     170     )
#     171 )
#     172 self.state = self.state[np.newaxis, :, :]
#
# File ~/dev/utokyo-qiskit-fall-fest-2025-qurl/ai_linear_function_synthesis/env.py:151, in AILinearFunctionSynthesis._make_quantum_circuit(self)
#     149 def _make_quantum_circuit(self) -> QuantumCircuit:
#     150     qc = QuantumCircuit(self.num_qubits)
# --> 151     for control, target in self.cnot_gates:
#     152         qc.cx(control, target)
#     153     return qc
#
# AttributeError: 'AILinearFunctionSynthesisDenseReward' object has no attribute 'cnot_gates'
